# %% [markdown]
# <a href="https://colab.research.google.com/github/eastmountaincode/DSC/blob/main/howToGetReviewDataFromGoogleMaps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The following is a documentation of the process of getting review data from Google Maps using a combination of the Google Places API and APIFY, a web scraping service (https://apify.com/). We use the Google Places API to get a list of businesses, and then we use APIFY to scrape the reviews.

# %%
#Importing libraries
import pandas as pd
import requests, json
import time

# %% [markdown]
# You will need an API key for the Google Places API. This can be obtained by making a Google Cloud account. You can learn how to obtain and API key at this link: https://developers.google.com/maps/documentation/places/web-service/get-api-key

# %%
api_key = 'api key goes here'

# %%
#Our base URL that we will attach parameters to
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

# %% [markdown]
# ## If getting data from just one location

# %%
# This is the text string on which to search. This should be altered depending on what you are looking for. 
# For example, you might set query as "Honky Tonk in Nashville, TN" or "Coffee shop in San Francisco".

query = "Urgent Care in Cincinnati"
  
#The query and API key are attached to the base URL
r = requests.get(url + 'query=' + query +
                        '&key=' + api_key)
  
#we convert the response from requestions into a json object
currentJSON = r.json()


#This is the dataframe where we'll keep all the info we get from the json(s). This initializes an empty dataframe with some defined columns.
holdingDF = pd.DataFrame(columns=["bizName", "placeID", "address", "placeTypes", "numOfRatings"])

#each json we get from our get request will have 50 businesses. If there are more businesses, there will be a 'next_page_token'.
#we want the following while loop to run at least once regardless of what we get in our json, so we set isToken to True.
isToken = True

while isToken:
  for business in range(len(currentJSON["results"])):

    bizName = currentJSON["results"][business]['name']
    placeID = currentJSON["results"][business]['place_id']
    address = currentJSON["results"][business]['formatted_address']

    allTypes = ""
    for eachType in currentJSON["results"][business]['types']:
      allTypes = allTypes + ", " + eachType
    allTypes = allTypes[1:]
    
    numOfRatings = currentJSON["results"][business]['user_ratings_total']

    new_row = {'bizName': bizName,
              'placeID': placeID,
              'address': address,
               'placeTypes': allTypes,
               'numOfRatings': numOfRatings}
    holdingDF = holdingDF.append(new_row, ignore_index=True)
  time.sleep(2)

  #The while loop checks if there is a next_page_token after the loop is complete, but we need this here to check if the FIRST page has one
  #If it does, go ahead and load the next JSON. Do display(currentJSON) if you want to get a better idea of how this works.
  if 'next_page_token' in currentJSON:
    r = requests.get(url + '&key=' + api_key + '&pagetoken=' + currentJSON['next_page_token'])
    
  currentJSON = r.json()
  if 'next_page_token' in currentJSON:
    isToken = True
  else:
    isToken = False

# %%
display(holdingDF)
# Out:
#                                               bizName  ... numOfRatings
# 0                   CareFirst Urgent Care - Hyde Park  ...          211
# 1                              Mt. Auburn Urgent Care  ...           75
# 2            The Christ Hospital - Urgent Care Center  ...           65
# 3                                 Medical Urgent Care  ...          253
# 4                   CareFirst Urgent Care - Winton Rd  ...           50
# 5                   CareFirst Urgent Care - Beechmont  ...          245
# 6   Cincinnati Children's Urgent Care - Burnet Campus  ...           16
# 7                                 Midtown Urgent Care  ...          330
# 8                     CareFirst Urgent Care - Kenwood  ...          142
# 9                       CareFirst Urgent Care - Delhi  ...          167
# 10                              Concentra Urgent Care  ...          486
# 11                        Doctors' Urgent Care Office  ...           45
# 12                    CareFirst Urgent Care - Norwood  ...          217
# 13                        Doctors' Urgent Care Office  ...          298
# 14                    TriHealth Priority Care Glenway  ...           60
# 15                         Community Urgent Care Plus  ...            5
# 16                                               MED+  ...          148
# 17                  American Family Care - Cincinnati  ...           29
# 18                                WellNow Urgent Care  ...          293
# 19       Cincinnati Children's Urgent Care - Anderson  ...           12
# 20                 CareFirst Urgent Care - Bridgetown  ...          135
# 21                                  The Little Clinic  ...           23
# 22                               Colerain Urgent Care  ...          323
# 23  Cincinnati Children's Urgent Care - Green Town...  ...           10
# 24                                WellNow Urgent Care  ...          271
# 25                                  The Little Clinic  ...           20
# 26                 TriHealth Priority Care - Anderson  ...           45
# 27  Mercy Health - Rookwood Medical Center Emergen...  ...            8
# 28                    CareFirst Urgent Care - Newport  ...           32
# 29                                  The Little Clinic  ...           11
# 30                                  The Little Clinic  ...           22
# 31                               Eastside Urgent Care  ...          522
# 32           The Christ Hospital - Urgent Care Center  ...           15
# 33                 CareFirst Urgent Care - Montgomery  ...           17
# 34                   CareFirst Urgent Care - Eastgate  ...          188
# 35  Mercy Health - Queen City Medical Center Emerg...  ...           11
# 36                                       MinuteClinic  ...            4
# 37  Highland Heights Urgent Care - St. Elizabeth P...  ...           36
# 38             Mercy Health - Rookwood Medical Center  ...           68
# 39                              Bluegrass Urgent Care  ...           50
#
# [40 rows x 5 columns]

# %% [markdown]
# ## If getting data from many locations

# %% [markdown]
# Maybe we don't want to perform just one search, maybe we want to perform several searches to get results from many different places. For example, what if we wanted to do search in every city in Ohio? This code can help us do that.

# %% [markdown]
# For this code, I used a CSV file containting every city in Ohio ordered by population. I got this list from this link: https://www.ohio-demographics.com/cities_by_population (it required a bit of cleaning).

# %%
#Importing location data
from google.colab import drive
drive.mount('/content/drive')
cityDF = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Yelp/OhioPopulationByCity.csv", index_col= 0)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
holdingDF = pd.DataFrame(columns=["bizName", "placeID", "address", "placeTypes", "numOfRatings"])
counter = 0

#I limited this search to the first 10 most populated cities in Ohio, hence the range(10).
for city in range(10):

  #The city name gets passed into the query based on the iteration index
  query = "Urgent Care in {}, Ohio".format(cityDF.loc[city, 'City'])

  r = requests.get(url + 'query=' + query +
                          '&key=' + api_key)
  currentJSON = r.json()
  isToken = True
  while isToken:
    for business in range(len(currentJSON["results"])):
      bizName = currentJSON["results"][business]['name']
      placeID = currentJSON["results"][business]['place_id']
      address = currentJSON["results"][business]['formatted_address']

      allTypes = ""
      for eachType in currentJSON["results"][business]['types']:
        allTypes = allTypes + ", " + eachType
      allTypes = allTypes[1:]
      
      numOfRatings = currentJSON["results"][business]['user_ratings_total']

      new_row = {'bizName': bizName,
                'placeID': placeID,
                'address': address,
                'placeTypes': allTypes,
                'numOfRatings': numOfRatings}
      holdingDF = holdingDF.append(new_row, ignore_index=True)

    
    time.sleep(2)
    if 'next_page_token' in currentJSON:
      r = requests.get(url + '&key=' + api_key + '&pagetoken=' + currentJSON['next_page_token'])
      
    # json method of response object convert
    #  json format data into python format data
    currentJSON = r.json()
    if 'next_page_token' in currentJSON:
      isToken = True
    else:
      isToken = False
  counter += 1
  print(str(round((counter/10)*100, 1)) + " percent complete")

#Since we're iterating over many cities, some of our search results may overlap. It's important to remove duplicates.
holdingDF = pd.DataFrame.drop_duplicates(holdingDF)
holdingDF.reset_index(drop=True, inplace=True)
# Out:
# 10.0 percent complete
# 20.0 percent complete
# 30.0 percent complete
# 40.0 percent complete
# 50.0 percent complete
# 60.0 percent complete
# 70.0 percent complete
# 80.0 percent complete
# 90.0 percent complete
# 100.0 percent complete

# %%
display(holdingDF)
# Out:
#                                         bizName  ... numOfRatings
# 0              OhioHealth Urgent Care Grandview  ...          120
# 1                           WellNow Urgent Care  ...          268
# 2                           Walk In Urgent Care  ...          161
# 3                           WellNow Urgent Care  ...          340
# 4     OhioHealth Urgent Care Gahanna/New Albany  ...          106
# ..                                          ...  ...          ...
# 338                  Health Express Urgent Care  ...          197
# 339                             Avon MediClinic  ...           28
# 340                       Superior Medical Care  ...            4
# 341  UH North Olmsted Health Center Urgent Care  ...            0
# 342         Cleveland Clinic Cole Eye Institute  ...            4
#
# [343 rows x 5 columns]

# %% [markdown]
# ## Now that we have a dataframe full of businesses from the Google Places API, the next step is to create a list of URLs we can feed to APIFY.

# %%
#Create a new empty dataframe
businessDFurlsDF = pd.DataFrame(columns=["name", "validURL", "placeID", "address", "city", "state", "dataSource"])

# %%
#For the placeID of every business...
for placeIDindex in range(len(holdingDF)):
  
  url = "https://maps.googleapis.com/maps/api/place/details/json?"
  placeIDiter = holdingDF.loc[placeIDindex, 'placeID']  

  #Notice that we're now feeding requests a 'place_id=' parameter now
  r = requests.get(url + 'place_id=' + placeIDiter +
                          '&fields=' + "name,rating,url,formatted_address" + '&key=' + api_key)
  currentJSON = r.json()

  bizName = currentJSON['result']['name']

  #This is the important part; the url in the json response for the business gotten by the placeID
  #The url contains a 'CID number'. When we append this CID number to the URL form below
  #It takes the form of a URL that APIFY can read. 
  placeIDtoSave = currentJSON['result']['url']
  theGoldenCID = placeIDtoSave.split('cid=')[1]
  validURL = 'https://www.google.com/maps/place/?cid=' + theGoldenCID

  address = currentJSON['result']['formatted_address']

  city = address.split(',')[1].strip()
  state = address.split(',')[2].strip()[0:2]

  #We've gotten some extra information like address ad city, but the important colimn is 'validURL'. 
  #This is what we'll use in the next step
  new_row = {'name': bizName,
            'validURL': validURL,
            'placeID': placeIDiter,
            'address': address,
            'city': city,
            'state': state,
              'dataSource': "GoogleMaps"}
  businessDFurlsDF = businessDFurlsDF.append(new_row, ignore_index=True)

# %%
validPlaceIDlist = []

for validURL in range(len(businessDFurlsDF)):
  validPlaceIDlist.append(businessDFurlsDF.loc[validURL, 'validURL'])

#remove duplicates
newlist = list(set(validPlaceIDlist))

# %%
display(newlist)
# Out:
# ['https://www.google.com/maps/place/?cid=10832212729393151300',
#  'https://www.google.com/maps/place/?cid=5282028492261820499',
#  'https://www.google.com/maps/place/?cid=1438511790338624599',
#  'https://www.google.com/maps/place/?cid=14058675919196144084',
#  'https://www.google.com/maps/place/?cid=3407590403897588708',
#  'https://www.google.com/maps/place/?cid=8382476842677630606',
#  'https://www.google.com/maps/place/?cid=8220539364398157171',
#  'https://www.google.com/maps/place/?cid=7477652847888702913',
#  'https://www.google.com/maps/place/?cid=4928561641340251280',
#  'https://www.google.com/maps/place/?cid=16192441780862287210',
#  'https://www.google.com/maps/place/?cid=17492464331890027860',
#  'https://www.google.com/maps/place/?cid=507793785810438747',
#  'https://www.google.com/maps/place/?cid=1519320540935787980',
#  'https://www.google.com/maps/place/?cid=11244346202899743015',
#  'https://www.google.com/maps/place/?cid=8428476724857553892',
#  'https://www.google.com/maps/place/?cid=3786881782762523220',
#  'https://www.google.com/maps/place/?cid=7657811960899090404',
#  'https://www.google.com/maps/place/?cid=4972466114915017143',
#  'https://www.google.com/maps/place/?cid=3158665038049328862',
#  'https://www.google.com/maps/place/?cid=10072289006386415383',
#  'https://www.google.com/maps/place/?cid=3525520067885358993',
#  'https://www.google.com/maps/place/?cid=2245848492770970223',
#  'https://www.google.com/maps/place/?cid=13217127122447645522',
#  'https://www.google.com/maps/place/?cid=10179739287315690904',
#  'https://www.google.com/maps/place/?cid=1704400998961844573',
#  'https://www.google.com/maps/place/?cid=12648754160673066733',
#  'https://www.google.com/maps/place/?cid=1663632226174017541',
#  'https://www.google.com/maps/place/?cid=8557891138070197852',
#  'https://www.google.com/maps/place/?cid=10631401137208566344',
#  'https://www.google.com/maps/place/?cid=10668284521883581704',
#  'https://www.google.com/maps/place/?cid=14937327985843952102',
#  'https://www.google.com/maps/place/?cid=17736260045058134975',
#  'https://www.google.com/maps/place/?cid=1540151906619053581',
#  'https://www.google.com/maps/place/?cid=9775231360504298478',
#  'https://www.google.com/maps/place/?cid=16853156954181500489',
#  'https://www.google.com/maps/place/?cid=686032211856427760',
#  'https://www.google.com/maps/place/?cid=2940596853443619429',
#  'https://www.google.com/maps/place/?cid=556872791552972093',
#  'https://www.google.com/maps/place/?cid=12914511340272247053',
#  'https://www.google.com/maps/place/?cid=730064462354398850',
#  'https://www.google.com/maps/place/?cid=17392626777574365687',
#  'https://www.google.com/maps/place/?cid=14792221152754710144',
#  'https://www.google.com/maps/place/?cid=8753232395224026830',
#  'https://www.google.com/maps/place/?cid=17238026305968699606',
#  'https://www.google.com/maps/place/?cid=13365355751546707378',
#  'https://www.google.com/maps/place/?cid=16909066858835415445',
#  'https://www.google.com/maps/place/?cid=4472956456972138831',
#  'https://www.google.com/maps/place/?cid=13510070437260923224',
#  'https://www.google.com/maps/place/?cid=7072060380703861434',
#  'https://www.google.com/maps/place/?cid=13498190172706330787',
#  'https://www.google.com/maps/place/?cid=854906639201226093',
#  'https://www.google.com/maps/place/?cid=14570013762504677084',
#  'https://www.google.com/maps/place/?cid=8909079701126191000',
#  'https://www.google.com/maps/place/?cid=6770957671016011029',
#  'https://www.google.com/maps/place/?cid=13635113179322889211',
#  'https://www.google.com/maps/place/?cid=14678451468942942143',
#  'https://www.google.com/maps/place/?cid=6557508078605160863',
#  'https://www.google.com/maps/place/?cid=11471838505689854224',
#  'https://www.google.com/maps/place/?cid=13945615214197287903',
#  'https://www.google.com/maps/place/?cid=16235818656069586145',
#  'https://www.google.com/maps/place/?cid=2549110805824667200',
#  'https://www.google.com/maps/place/?cid=3535658195831292443',
#  'https://www.google.com/maps/place/?cid=6939759881572678163',
#  'https://www.google.com/maps/place/?cid=6019691456760398532',
#  'https://www.google.com/maps/place/?cid=155208438693374054',
#  'https://www.google.com/maps/place/?cid=5505637268657662787',
#  'https://www.google.com/maps/place/?cid=14120160152492644306',
#  'https://www.google.com/maps/place/?cid=11091410865668905532',
#  'https://www.google.com/maps/place/?cid=441075414811411792',
#  'https://www.google.com/maps/place/?cid=4342337595261067423',
#  'https://www.google.com/maps/place/?cid=10251282850316801440',
#  'https://www.google.com/maps/place/?cid=1441146336158384098',
#  'https://www.google.com/maps/place/?cid=5159751747093355599',
#  'https://www.google.com/maps/place/?cid=18103449646341861825',
#  'https://www.google.com/maps/place/?cid=6248839573823692583',
#  'https://www.google.com/maps/place/?cid=12275382531195110103',
#  'https://www.google.com/maps/place/?cid=17921639478594370383',
#  'https://www.google.com/maps/place/?cid=15136941166525564227',
#  'https://www.google.com/maps/place/?cid=6661885305599107329',
#  'https://www.google.com/maps/place/?cid=855963151280306799',
#  'https://www.google.com/maps/place/?cid=11250774981225830160',
#  'https://www.google.com/maps/place/?cid=17325804026186873328',
#  'https://www.google.com/maps/place/?cid=12091812232944360280',
#  'https://www.google.com/maps/place/?cid=10462358500169384033',
#  'https://www.google.com/maps/place/?cid=15746306800080589805',
#  'https://www.google.com/maps/place/?cid=2550204344105405646',
#  'https://www.google.com/maps/place/?cid=1419330368027211745',
#  'https://www.google.com/maps/place/?cid=17728971512701059985',
#  'https://www.google.com/maps/place/?cid=2085458230299189507',
#  'https://www.google.com/maps/place/?cid=538077315293974936',
#  'https://www.google.com/maps/place/?cid=14251016468611589594',
#  'https://www.google.com/maps/place/?cid=13919229521395000057',
#  'https://www.google.com/maps/place/?cid=15551432329760450359',
#  'https://www.google.com/maps/place/?cid=7153571593767127255',
#  'https://www.google.com/maps/place/?cid=7558938490319409044',
#  'https://www.google.com/maps/place/?cid=1712998017452193806',
#  'https://www.google.com/maps/place/?cid=17689136868948156625',
#  'https://www.google.com/maps/place/?cid=16482825445093242922',
#  'https://www.google.com/maps/place/?cid=4093327433917765790',
#  'https://www.google.com/maps/place/?cid=1800843263944582147',
#  'https://www.google.com/maps/place/?cid=9302093388747639254',
#  'https://www.google.com/maps/place/?cid=16476736764241352522',
#  'https://www.google.com/maps/place/?cid=10954381443202785860',
#  'https://www.google.com/maps/place/?cid=5563406904973466784',
#  'https://www.google.com/maps/place/?cid=5273384831576902024',
#  'https://www.google.com/maps/place/?cid=13670186843977317029',
#  'https://www.google.com/maps/place/?cid=3579233372906925897',
#  'https://www.google.com/maps/place/?cid=9847727692836838802',
#  'https://www.google.com/maps/place/?cid=2611290641294472830',
#  'https://www.google.com/maps/place/?cid=16116184690769368473',
#  'https://www.google.com/maps/place/?cid=2404474904029862573',
#  'https://www.google.com/maps/place/?cid=7174747934426648940',
#  'https://www.google.com/maps/place/?cid=9387488928738552905',
#  'https://www.google.com/maps/place/?cid=13941449412804962855',
#  'https://www.google.com/maps/place/?cid=8515950139941716924',
#  'https://www.google.com/maps/place/?cid=8012875954407612874',
#  'https://www.google.com/maps/place/?cid=6380290802559443950',
#  'https://www.google.com/maps/place/?cid=18035184104399416210',
#  'https://www.google.com/maps/place/?cid=11640523409272252212',
#  'https://www.google.com/maps/place/?cid=18332066299180647637',
#  'https://www.google.com/maps/place/?cid=17394790811035581522',
#  'https://www.google.com/maps/place/?cid=17972797370970209961',
#  'https://www.google.com/maps/place/?cid=1062626571885482398',
#  'https://www.google.com/maps/place/?cid=17673828860518627701',
#  'https://www.google.com/maps/place/?cid=715562790575317364',
#  'https://www.google.com/maps/place/?cid=16064179606120849912',
#  'https://www.google.com/maps/place/?cid=906580953069780453',
#  'https://www.google.com/maps/place/?cid=276061092267953179',
#  'https://www.google.com/maps/place/?cid=14134881529418306809',
#  'https://www.google.com/maps/place/?cid=2743648645157969279',
#  'https://www.google.com/maps/place/?cid=16586442850620147995',
#  'https://www.google.com/maps/place/?cid=6076396178499465781',
#  'https://www.google.com/maps/place/?cid=828698590786733455',
#  'https://www.google.com/maps/place/?cid=1868651010579731635',
#  'https://www.google.com/maps/place/?cid=17963295354362080244',
#  'https://www.google.com/maps/place/?cid=5450233962445217334',
#  'https://www.google.com/maps/place/?cid=16667396819956443882',
#  'https://www.google.com/maps/place/?cid=10944058666859503312',
#  'https://www.google.com/maps/place/?cid=1929343842866661755',
#  'https://www.google.com/maps/place/?cid=16493577162226563345',
#  'https://www.google.com/maps/place/?cid=8233274698567289059',
#  'https://www.google.com/maps/place/?cid=16466275253363894910',
#  'https://www.google.com/maps/place/?cid=13934288906345647424',
#  'https://www.google.com/maps/place/?cid=9194801375741693173',
#  'https://www.google.com/maps/place/?cid=9599039827474831482',
#  'https://www.google.com/maps/place/?cid=14620845026158897255',
#  'https://www.google.com/maps/place/?cid=1326289135971288401',
#  'https://www.google.com/maps/place/?cid=12256635966660992013',
#  'https://www.google.com/maps/place/?cid=7115057182235789797',
#  'https://www.google.com/maps/place/?cid=3080410915299073213',
#  'https://www.google.com/maps/place/?cid=16650612442814792993',
#  'https://www.google.com/maps/place/?cid=4959740416980360573',
#  'https://www.google.com/maps/place/?cid=3982952530091162184',
#  'https://www.google.com/maps/place/?cid=14719173448972453807',
#  'https://www.google.com/maps/place/?cid=14957798139672027207',
#  'https://www.google.com/maps/place/?cid=15004674654747794637',
#  'https://www.google.com/maps/place/?cid=9182527254453736059',
#  'https://www.google.com/maps/place/?cid=18180922791107807782',
#  'https://www.google.com/maps/place/?cid=3886499680503591646',
#  'https://www.google.com/maps/place/?cid=16053038458827735197',
#  'https://www.google.com/maps/place/?cid=5400187268627270648',
#  'https://www.google.com/maps/place/?cid=3234801021113986468',
#  'https://www.google.com/maps/place/?cid=17662315190032674431',
#  'https://www.google.com/maps/place/?cid=6925608320168959351',
#  'https://www.google.com/maps/place/?cid=13466208654279461501',
#  'https://www.google.com/maps/place/?cid=15547716838010319230',
#  'https://www.google.com/maps/place/?cid=353127518324011671',
#  'https://www.google.com/maps/place/?cid=5202934767827176608',
#  'https://www.google.com/maps/place/?cid=16784170606969862173',
#  'https://www.google.com/maps/place/?cid=658187748577538384',
#  'https://www.google.com/maps/place/?cid=2303785290114903754',
#  'https://www.google.com/maps/place/?cid=12425726376402911376',
#  'https://www.google.com/maps/place/?cid=1637848291486873170',
#  'https://www.google.com/maps/place/?cid=91505444905425527',
#  'https://www.google.com/maps/place/?cid=9193184311897559404',
#  'https://www.google.com/maps/place/?cid=2736744294862341046',
#  'https://www.google.com/maps/place/?cid=13842258195170684400',
#  'https://www.google.com/maps/place/?cid=757466696066540275',
#  'https://www.google.com/maps/place/?cid=7999003288742093052',
#  'https://www.google.com/maps/place/?cid=16984813847197047095',
#  'https://www.google.com/maps/place/?cid=14773236841180408668',
#  'https://www.google.com/maps/place/?cid=10718087789160207853',
#  'https://www.google.com/maps/place/?cid=7948018762252308562',
#  'https://www.google.com/maps/place/?cid=7912447735102679776',
#  'https://www.google.com/maps/place/?cid=13808715199763015791',
#  'https://www.google.com/maps/place/?cid=6322340450149323069',
#  'https://www.google.com/maps/place/?cid=12754465055151201956',
#  'https://www.google.com/maps/place/?cid=9105071077219477058',
#  'https://www.google.com/maps/place/?cid=14608448908972313218',
#  'https://www.google.com/maps/place/?cid=4850721777528894050',
#  'https://www.google.com/maps/place/?cid=15679794124751777193',
#  'https://www.google.com/maps/place/?cid=11489091018180529523',
#  'https://www.google.com/maps/place/?cid=3621773196483541969',
#  'https://www.google.com/maps/place/?cid=7020528410620403962',
#  'https://www.google.com/maps/place/?cid=12181989332822388966',
#  'https://www.google.com/maps/place/?cid=22683426921019840',
#  'https://www.google.com/maps/place/?cid=13891172667926982308',
#  'https://www.google.com/maps/place/?cid=13442231765479513562',
#  'https://www.google.com/maps/place/?cid=18158635952415367230',
#  'https://www.google.com/maps/place/?cid=15734800529078871571',
#  'https://www.google.com/maps/place/?cid=10059316558620231310',
#  'https://www.google.com/maps/place/?cid=18108049998449064325',
#  'https://www.google.com/maps/place/?cid=4772958751078690533',
#  'https://www.google.com/maps/place/?cid=2084418806556454658',
#  'https://www.google.com/maps/place/?cid=1395122515370563488',
#  'https://www.google.com/maps/place/?cid=6534644545234035423',
#  'https://www.google.com/maps/place/?cid=940158577017722624',
#  'https://www.google.com/maps/place/?cid=15434406814123105731',
#  'https://www.google.com/maps/place/?cid=4101398589834261050',
#  'https://www.google.com/maps/place/?cid=4630817539359463656',
#  'https://www.google.com/maps/place/?cid=2362885327842945440',
#  'https://www.google.com/maps/place/?cid=10334076736942440526',
#  'https://www.google.com/maps/place/?cid=5189377286697432618',
#  'https://www.google.com/maps/place/?cid=10638008474896555587',
#  'https://www.google.com/maps/place/?cid=14124134722953921759',
#  'https://www.google.com/maps/place/?cid=15174570870170598438',
#  'https://www.google.com/maps/place/?cid=5630859090189356733',
#  'https://www.google.com/maps/place/?cid=11179380815928539839',
#  'https://www.google.com/maps/place/?cid=3791678915902332471',
#  'https://www.google.com/maps/place/?cid=6618719202421496188',
#  'https://www.google.com/maps/place/?cid=1856529405403398439',
#  'https://www.google.com/maps/place/?cid=8707539211149165111',
#  'https://www.google.com/maps/place/?cid=5306015810039892164',
#  'https://www.google.com/maps/place/?cid=5745034893518620864',
#  'https://www.google.com/maps/place/?cid=12058407285544960833',
#  'https://www.google.com/maps/place/?cid=7994026466474562010',
#  'https://www.google.com/maps/place/?cid=1934245290127578229',
#  'https://www.google.com/maps/place/?cid=1308109517980597221',
#  'https://www.google.com/maps/place/?cid=298733215115925224',
#  'https://www.google.com/maps/place/?cid=93008074588073705',
#  'https://www.google.com/maps/place/?cid=12760619606730270017',
#  'https://www.google.com/maps/place/?cid=2769318063029174075',
#  'https://www.google.com/maps/place/?cid=13956307530605856158',
#  'https://www.google.com/maps/place/?cid=12502965420362980090',
#  'https://www.google.com/maps/place/?cid=15351548921017827666',
#  'https://www.google.com/maps/place/?cid=8460958924711445299',
#  'https://www.google.com/maps/place/?cid=5877490604344416201',
#  'https://www.google.com/maps/place/?cid=7346708505243703632',
#  'https://www.google.com/maps/place/?cid=1963782036650749530',
#  'https://www.google.com/maps/place/?cid=16540389173204386984',
#  'https://www.google.com/maps/place/?cid=7475578585845308763',
#  'https://www.google.com/maps/place/?cid=9739825346658185868',
#  'https://www.google.com/maps/place/?cid=17075920276067778544',
#  'https://www.google.com/maps/place/?cid=18375685761389878844',
#  'https://www.google.com/maps/place/?cid=7301840363704216901',
#  'https://www.google.com/maps/place/?cid=8445949659850157373',
#  'https://www.google.com/maps/place/?cid=1242344162895306283',
#  'https://www.google.com/maps/place/?cid=1078021994727345116',
#  'https://www.google.com/maps/place/?cid=2652546945487070181',
#  'https://www.google.com/maps/place/?cid=657759619548908153',
#  'https://www.google.com/maps/place/?cid=13122003863006425713',
#  'https://www.google.com/maps/place/?cid=4714386168150523838',
#  'https://www.google.com/maps/place/?cid=10951632039273708749',
#  'https://www.google.com/maps/place/?cid=7565449209741653498',
#  'https://www.google.com/maps/place/?cid=17563607567135813981',
#  'https://www.google.com/maps/place/?cid=11452104506760838817',
#  'https://www.google.com/maps/place/?cid=13865013253691313940',
#  'https://www.google.com/maps/place/?cid=10008874304432585901',
#  'https://www.google.com/maps/place/?cid=6478530342214822540',
#  'https://www.google.com/maps/place/?cid=1675922600876602507',
#  'https://www.google.com/maps/place/?cid=3749524259120959949',
#  'https://www.google.com/maps/place/?cid=5456485991675382707',
#  'https://www.google.com/maps/place/?cid=4233156675703587919',
#  'https://www.google.com/maps/place/?cid=386732980943927326',
#  'https://www.google.com/maps/place/?cid=9630679891742715683',
#  'https://www.google.com/maps/place/?cid=6672968194789498731',
#  'https://www.google.com/maps/place/?cid=12221179654492843784',
#  'https://www.google.com/maps/place/?cid=1426614034517329605',
#  'https://www.google.com/maps/place/?cid=235464151316314061',
#  'https://www.google.com/maps/place/?cid=13051908003093787174',
#  'https://www.google.com/maps/place/?cid=17668844520980105071',
#  'https://www.google.com/maps/place/?cid=7552817097787813623',
#  'https://www.google.com/maps/place/?cid=4000322148014214936',
#  'https://www.google.com/maps/place/?cid=9861740982088351113',
#  'https://www.google.com/maps/place/?cid=3291057271540359443',
#  'https://www.google.com/maps/place/?cid=13082411229174467979',
#  'https://www.google.com/maps/place/?cid=4230312660275825626',
#  'https://www.google.com/maps/place/?cid=7840542059110187403',
#  'https://www.google.com/maps/place/?cid=7004069885409930200',
#  'https://www.google.com/maps/place/?cid=485558354704572675',
#  'https://www.google.com/maps/place/?cid=16914510460952945975',
#  'https://www.google.com/maps/place/?cid=10885685490656967843',
#  'https://www.google.com/maps/place/?cid=11965528551477109309',
#  'https://www.google.com/maps/place/?cid=4681981168089389808',
#  'https://www.google.com/maps/place/?cid=12101030874558370744',
#  'https://www.google.com/maps/place/?cid=196783893038698384',
#  'https://www.google.com/maps/place/?cid=8060263473411853759',
#  'https://www.google.com/maps/place/?cid=4986565705735252344',
#  'https://www.google.com/maps/place/?cid=13698494319117684940',
#  'https://www.google.com/maps/place/?cid=5829325256638750343',
#  'https://www.google.com/maps/place/?cid=9587979148902680642',
#  'https://www.google.com/maps/place/?cid=13989905076003148329',
#  'https://www.google.com/maps/place/?cid=2132451729908304017',
#  'https://www.google.com/maps/place/?cid=4955403089802608765',
#  'https://www.google.com/maps/place/?cid=9785198656630627751',
#  'https://www.google.com/maps/place/?cid=8311423902845245370',
#  'https://www.google.com/maps/place/?cid=4757718254057209630',
#  'https://www.google.com/maps/place/?cid=1572598305102140740',
#  'https://www.google.com/maps/place/?cid=1246774741171253500',
#  'https://www.google.com/maps/place/?cid=13288689844969256281',
#  'https://www.google.com/maps/place/?cid=8036478296422913658',
#  'https://www.google.com/maps/place/?cid=17129510263831198687',
#  'https://www.google.com/maps/place/?cid=8558455892528322990',
#  'https://www.google.com/maps/place/?cid=840071692824495741',
#  'https://www.google.com/maps/place/?cid=18191841631049725797',
#  'https://www.google.com/maps/place/?cid=16143921247427326623',
#  'https://www.google.com/maps/place/?cid=13513412356401455830',
#  'https://www.google.com/maps/place/?cid=7617146005132228238',
#  'https://www.google.com/maps/place/?cid=5870190183115537944',
#  'https://www.google.com/maps/place/?cid=17087100206366600002',
#  'https://www.google.com/maps/place/?cid=1259296064425356519',
#  'https://www.google.com/maps/place/?cid=7823066690114861056',
#  'https://www.google.com/maps/place/?cid=15014420986434934581',
#  'https://www.google.com/maps/place/?cid=8258262814694943904',
#  'https://www.google.com/maps/place/?cid=8568447413501052109',
#  'https://www.google.com/maps/place/?cid=9787526988369501523',
#  'https://www.google.com/maps/place/?cid=3038685804894469684',
#  'https://www.google.com/maps/place/?cid=635575956375692780',
#  'https://www.google.com/maps/place/?cid=12020083827140265221',
#  'https://www.google.com/maps/place/?cid=8742678392242056310',
#  'https://www.google.com/maps/place/?cid=5207214486815413584',
#  'https://www.google.com/maps/place/?cid=5841292152456093683',
#  'https://www.google.com/maps/place/?cid=14206923832446672134',
#  'https://www.google.com/maps/place/?cid=3742819629789992821',
#  'https://www.google.com/maps/place/?cid=14038322563014766021',
#  'https://www.google.com/maps/place/?cid=6587586408327439687',
#  'https://www.google.com/maps/place/?cid=4223013681808385716',
#  'https://www.google.com/maps/place/?cid=17365711418838294185',
#  'https://www.google.com/maps/place/?cid=5520811169054834852',
#  'https://www.google.com/maps/place/?cid=12948525653708615793',
#  'https://www.google.com/maps/place/?cid=14682111749506734526',
#  'https://www.google.com/maps/place/?cid=3669604900779799514',
#  'https://www.google.com/maps/place/?cid=13839041638716312234',
#  'https://www.google.com/maps/place/?cid=9616687058466998316',
#  'https://www.google.com/maps/place/?cid=2363330924157567988',
#  'https://www.google.com/maps/place/?cid=9572025236805469913',
#  'https://www.google.com/maps/place/?cid=652912755831149737',
#  'https://www.google.com/maps/place/?cid=2417085921506935205',
#  'https://www.google.com/maps/place/?cid=9613409257984899510',
#  'https://www.google.com/maps/place/?cid=12750016998141064425',
#  'https://www.google.com/maps/place/?cid=1325028962148400526',
#  'https://www.google.com/maps/place/?cid=7325080472213819911',
#  'https://www.google.com/maps/place/?cid=5846089272671623304']

# %% [markdown]
# ## Now download the list

# %%
from google.colab import files
df = pd.DataFrame(newlist)
df.to_csv('placeIDlistforAPIFY.csv', index=False)
files.download('placeIDlistforAPIFY.csv')

# %% [markdown]
# ## Now we go to APIFY. Create a new "task" and choose the Google Maps Scraper. Plug in the CSV list that we made in the last step to "Start URLs" (choose upload text file). Remove search terms. Set max crawled places to 0. Under output configuration set max reviews to 99999. Set max images to 0. Uncheck include popular times. Sort reviews by "Newest". Run the scraper. APIFY will give you a JSON file. Download it and bring it into this code.

# %% [markdown]
# Using the previous code, I ran a search for "Urgent Care in Cincinnati", received 40 businesses, and put the CSV file in APIFY. I got back a JSON, which I'm importing into the code now.

# %%
#Mount the drive in case we haven't already.
from google.colab import drive
drive.mount('/content/drive')

dataFromAPIFYDF = pd.read_json("/content/drive/My Drive/Colab Notebooks/Google/GoogleTutorialData.json")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## If you want to make a dataframe where each row is a separate review...

# %%
#REVIEW SCALE


reviewScaleDF = pd.DataFrame(columns=["businessTitle", "googleURL", "CIDnum", "phoneNum", "address", "city", "state", "businessRating", "reviewDate", "reviewText", "reviewRating", "bizType", "dataSource"])
counter = 0
for business in range(len(dataFromAPIFYDF)):
  #Our search will have given us businesses that are not urgent care centers, and since Cincinnati is very close to Kentucky, we may get some results from KY
  #This next step filters results to only include businesses that are in Ohio and that have the categoryName 'Urgent care center'
  if dataFromAPIFYDF.loc[business, 'categoryName'] == 'Urgent care center' and dataFromAPIFYDF.loc[business, 'address'].split(',')[2].strip()[0:2] == 'OH':
    for review in range(len(dataFromAPIFYDF.loc[business, 'reviews'])):

      businessTitle = dataFromAPIFYDF.loc[business, 'title']
      directURL = dataFromAPIFYDF.loc[business, 'placeId']
      placeIDtoSave = dataFromAPIFYDF.loc[business, 'placeId']

      theGoldenCID = placeIDtoSave.split('cid=')[1]

      phoneNum = dataFromAPIFYDF.loc[business, 'phone']
      address = dataFromAPIFYDF.loc[business, 'address']
      city = address.split(',')[1].strip()
      state = address.split(',')[2].strip()[0:2]

      overallRating = dataFromAPIFYDF.loc[business, 'totalScore']
      theDate = dataFromAPIFYDF.loc[business, 'reviews'][review]['publishedAtDate'][0:10]

      reviewText = dataFromAPIFYDF.loc[business, 'reviews'][review]['text']
      reviewRating = dataFromAPIFYDF.loc[business, 'reviews'][review]['stars']


      if reviewText:
        new_row = {'businessTitle': businessTitle,
                  'googleURL': directURL,
                  'CIDnum': theGoldenCID,
                  'phoneNum': phoneNum,
                  'address': address,
                  'city': city,
                  'state': state,
                  'businessRating': overallRating,
                  'reviewDate': theDate,
                  "reviewText": reviewText,
                  "reviewRating": reviewRating,
                  "bizType": "urgentCare",
                  "dataSource": "Google"}
        reviewScaleDF = reviewScaleDF.append(new_row, ignore_index=True)
  counter += 1
  number = (counter/len(dataFromAPIFYDF)*100)
  print(round(number, 2))
# Out:
# 2.5
# 5.0
# 7.5
# 10.0
# 12.5
# 15.0
# 17.5
# 20.0
# 22.5
# 25.0
# 27.5
# 30.0
# 32.5
# 35.0
# 37.5
# 40.0
# 42.5
# 45.0
# 47.5
# 50.0
# 52.5
# 55.0
# 57.5
# 60.0
# 62.5
# 65.0
# 67.5
# 70.0
# 72.5
# 75.0
# 77.5
# 80.0
# 82.5
# 85.0
# 87.5
# 90.0
# 92.5
# 95.0
# 97.5
# 100.0

# %%
display(reviewScaleDF)
# Out:
#                                           businessTitle  ... dataSource
# 0                                          MinuteClinic  ...     Google
# 1                                          MinuteClinic  ...     Google
# 2                                          MinuteClinic  ...     Google
# 3                    CareFirst Urgent Care - Montgomery  ...     Google
# 4                    CareFirst Urgent Care - Montgomery  ...     Google
# ...                                                 ...  ...        ...
# 2721  Cincinnati Children's Urgent Care - Green Town...  ...     Google
# 2722  Cincinnati Children's Urgent Care - Green Town...  ...     Google
# 2723  Cincinnati Children's Urgent Care - Green Town...  ...     Google
# 2724  Cincinnati Children's Urgent Care - Green Town...  ...     Google
# 2725  Cincinnati Children's Urgent Care - Green Town...  ...     Google
#
# [2726 rows x 13 columns]

# %%
from google.colab import files
reviewScaleDF.to_csv("reviewScaleUrgentCareGoogle.csv")
files.download("reviewScaleUrgentCareGoogle.csv")

# %% [markdown]
# ## If you want to make a dataframe where each row is one business, and the review text is stored in a column with one big review, a concatenation of ALL that reviews for that business...

# %%
#INSTITUTION SCALE


institutionalScaleDF = pd.DataFrame(columns=["businessTitle", "googleURL", "CIDnum", "phoneNum", "address", "city", "state", "businessRating", "bigText", "numberOfReviews", "bizType", "dataSource"])
counter = 0
for business in range(len(dataFromAPIFYDF)):
  #Our search will have given us businesses that are not urgent care centers, and since Cincinnati is very close to Kentucky, we may get some results from KY
  #This next step filters results to only include businesses that are in Ohio and that have the categoryName 'Urgent care center'
  if dataFromAPIFYDF.loc[business, 'categoryName'] == 'Urgent care center' and dataFromAPIFYDF.loc[business, 'address'].split(',')[2].strip()[0:2] == 'OH':

    businessTitle = dataFromAPIFYDF.loc[business, 'title']
    directURL = dataFromAPIFYDF.loc[business, 'placeId']
    placeIDtoSave = dataFromAPIFYDF.loc[business, 'placeId']

    theGoldenCID = placeIDtoSave.split('cid=')[1]

    phoneNum = dataFromAPIFYDF.loc[business, 'phone']
    address = dataFromAPIFYDF.loc[business, 'address']
    city = address.split(',')[1].strip()
    state = address.split(',')[2].strip()[0:2]

    overallRating = dataFromAPIFYDF.loc[business, 'totalScore']

    bigText = ""
    numOfReviews = 0
    #For each reivew...
    for review in range(len(dataFromAPIFYDF.loc[business, 'reviews'])):
      #If the review has text, meaning it's not just a rating based on number of stars...
      if dataFromAPIFYDF.loc[business, 'reviews'][review]['text']:
        reviewText = dataFromAPIFYDF.loc[business, 'reviews'][review]['text']
        #...append the review to this string called big text, and separate individual reviews with a newline, 10 tildes, and another newline.
        bigText = bigText + reviewText
        bigText = bigText + "\n" + "~~~~~~~~~~" + "\n"
        numOfReviews += 1
        


    #Make sure the business had a least ONE review with text in it...
    if bigText:
      new_row = {'businessTitle': businessTitle,
                'googleURL': directURL,
                'CIDnum': theGoldenCID,
                'phoneNum': phoneNum,
                'address': address,
                'city': city,
                'state': state,
                'businessRating': overallRating,
                "bigText": bigText,
                "numberOfReviews": numOfReviews,
                "bizType": "urgentCare",
                "dataSource": "Google"}
      institutionalScaleDF = institutionalScaleDF.append(new_row, ignore_index=True)
  counter += 1
  number = (counter/len(dataFromAPIFYDF)*100)
  print(round(number, 2))
# Out:
# 2.5
# 5.0
# 7.5
# 10.0
# 12.5
# 15.0
# 17.5
# 20.0
# 22.5
# 25.0
# 27.5
# 30.0
# 32.5
# 35.0
# 37.5
# 40.0
# 42.5
# 45.0
# 47.5
# 50.0
# 52.5
# 55.0
# 57.5
# 60.0
# 62.5
# 65.0
# 67.5
# 70.0
# 72.5
# 75.0
# 77.5
# 80.0
# 82.5
# 85.0
# 87.5
# 90.0
# 92.5
# 95.0
# 97.5
# 100.0

# %%
display(institutionalScaleDF)
# Out:
#                                         businessTitle  ... dataSource
# 0                                        MinuteClinic  ...     Google
# 1                  CareFirst Urgent Care - Montgomery  ...     Google
# 2                   CareFirst Urgent Care - Beechmont  ...     Google
# 3                                Eastside Urgent Care  ...     Google
# 4                                 Medical Urgent Care  ...     Google
# 5                     TriHealth Priority Care Glenway  ...     Google
# 6                                 WellNow Urgent Care  ...     Google
# 7                                 WellNow Urgent Care  ...     Google
# 8                         Doctors' Urgent Care Office  ...     Google
# 9                   American Family Care - Cincinnati  ...     Google
# 10                             Mt. Auburn Urgent Care  ...     Google
# 11                        Doctors' Urgent Care Office  ...     Google
# 12                  CareFirst Urgent Care - Winton Rd  ...     Google
# 13                 CareFirst Urgent Care - Bridgetown  ...     Google
# 14                      CareFirst Urgent Care - Delhi  ...     Google
# 15                                               MED+  ...     Google
# 16           The Christ Hospital - Urgent Care Center  ...     Google
# 17                    CareFirst Urgent Care - Kenwood  ...     Google
# 18                 TriHealth Priority Care - Anderson  ...     Google
# 19  Cincinnati Children's Urgent Care - Burnet Campus  ...     Google
# 20       Cincinnati Children's Urgent Care - Anderson  ...     Google
# 21                         Community Urgent Care Plus  ...     Google
# 22                    CareFirst Urgent Care - Norwood  ...     Google
# 23                               Colerain Urgent Care  ...     Google
# 24                                Midtown Urgent Care  ...     Google
# 25                  CareFirst Urgent Care - Hyde Park  ...     Google
# 26                   CareFirst Urgent Care - Eastgate  ...     Google
# 27  Cincinnati Children's Urgent Care - Green Town...  ...     Google
#
# [28 rows x 12 columns]

# %%
from google.colab import files
institutionalScaleDF.to_csv("institutionalScaleUrgentCareGoogle.csv")
files.download("institutionalScaleUrgentCareGoogle.csv")
